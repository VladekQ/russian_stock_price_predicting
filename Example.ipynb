# %% [markdown]
# # Import module

# %%
import stocks_nn_vap as snv

# %% [markdown]
# # Getting Stock Prices

# %%
# %%time

symbols = ['ROSN', 'GAZP']
datasets = snv.get_stocks_data(symbols=symbols)
# Out:
# CPU times: total: 31.5 s
# Wall time: 57.1 s

# %%
datasets['ROSN']
# Out:
#              close
# 2006-07-19  203.95
# 2006-07-20  203.26
# 2006-07-21  202.00
# 2006-07-24  201.99
# 2006-07-25  202.69
# ...            ...
# 2024-04-30  582.00
# 2024-05-02  582.30
# 2024-05-03  582.30
# 2024-05-06  579.05
# 2024-05-07  579.95
#
# [4473 rows x 1 columns]

# %% [markdown]
# # Preprocessing Data

# %%
preprocessed_datasets = snv.preprocess_stocks_data(datasets)
# Out:
# ROSN data is ready. Time takes: 0 seconds
# GAZP data is ready. Time takes: 0 seconds

# %% [markdown]
# # Build and Fit models

# %%
# %%time

snv.build_fit_stocks_model(preprocessed_datasets, symbols=symbols)
# Out:
# ROSN
# 4451 4451
# 4441 4441
# 4441 4441
# GAZP
# 4573 4573
# 4563 4563
# 4563 4563
# 139/139 [==============================] - 0s 1ms/step - loss: 4.4476
# 139/139 [==============================] - 0s 761us/step
# ROSN data is ready. Time takes: 16 seconds. MAE: 4.45 rub. R2: 1.00
# 143/143 [==============================] - 0s 2ms/step - loss: 2.8490
# 143/143 [==============================] - 0s 965us/step
# GAZP data is ready. Time takes: 12 seconds. MAE: 2.85 rub. R2: 0.99
# 139/139 [==============================] - 0s 1ms/step - loss: 4.3505
# 139/139 [==============================] - 0s 768us/step
# ROSN data is ready. Time takes: 14 seconds. MAE: 4.35 rub. R2: 1.00
# 143/143 [==============================] - 0s 1ms/step - loss: 2.8322
# 143/143 [==============================] - 0s 775us/step
# GAZP data is ready. Time takes: 5 seconds. MAE: 2.83 rub. R2: 0.99
# 139/139 [==============================] - 0s 2ms/step - loss: 4.3977
# 139/139 [==============================] - 0s 812us/step
# ROSN data is ready. Time takes: 33 seconds. MAE: 4.40 rub. R2: 1.00
# 143/143 [==============================] - 0s 1ms/step - loss: 2.8050
# 143/143 [==============================] - 0s 725us/step
# GAZP data is ready. Time takes: 15 seconds. MAE: 2.80 rub. R2: 0.99
# 139/139 [==============================] - 0s 2ms/step - loss: 4.2868
# 139/139 [==============================] - 0s 920us/step
# ROSN data is ready. Time takes: 33 seconds. MAE: 4.29 rub. R2: 1.00
# 143/143 [==============================] - 0s 2ms/step - loss: 2.8036
# 143/143 [==============================] - 0s 852us/step
# GAZP data is ready. Time takes: 8 seconds. MAE: 2.80 rub. R2: 0.99
# 139/139 [==============================] - 0s 2ms/step - loss: 4.1628
# 139/139 [==============================] - 0s 1ms/step
# ROSN data is ready. Time takes: 52 seconds. MAE: 4.16 rub. R2: 1.00
# 143/143 [==============================] - 0s 2ms/step - loss: 2.8501
# 143/143 [==============================] - 0s 1ms/step
# GAZP data is ready. Time takes: 15 seconds. MAE: 2.85 rub. R2: 0.99
# 139/139 [==============================] - 0s 2ms/step - loss: 4.1976
# 139/139 [==============================] - 0s 1ms/step
# ROSN data is ready. Time takes: 22 seconds. MAE: 4.20 rub. R2: 1.00
# 143/143 [==============================] - 0s 2ms/step - loss: 2.7867
# 143/143 [==============================] - 0s 1ms/step
# GAZP data is ready. Time takes: 16 seconds. MAE: 2.79 rub. R2: 0.99
# All models have been saved in "models_" folder
# CPU times: total: 5min 20s
# Wall time: 4min 2s

# %% [markdown]
# # Predicting

# %%
# %%time

preds = snv.predict_future_stock_price(preprocessed_datasets, future_days=10, symbol='ROSN')
# Out:
# CPU times: total: 28.6 s
# Wall time: 22.6 s

# %%
preds
# Out:
#                 medium       small       large  mean_prediction
# 2024-05-08  581.854431  579.706177  580.486572       580.682373
# 2024-05-09  579.137146  579.189514  576.968384       578.431702
# 2024-05-10  577.976562  580.739075  570.922058       576.545898
# 2024-05-13  578.879517  581.184082  574.130188       578.064636
# 2024-05-14  576.204468  582.518860  571.327454       576.683594
# 2024-05-15  575.270508  583.112427  569.063416       575.815430
# 2024-05-16  577.000977  583.107056  566.388062       575.498718
# 2024-05-17  580.030090  582.993958  562.367920       575.130676
