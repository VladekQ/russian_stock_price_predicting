# %% [markdown]
# # Import module

# %%
import stocks_nn_vap as snv

# %% [markdown]
# # Getting Stock Prices

# %%
datasets = snv.get_stocks_data(start_time='2016-01-01', end_time='2024-04-01', symbols=['GAZP'])
# Out:
# GAZP data is ready. Time takes: 27 seconds
# Getting data is done!

# %% [markdown]
# # Preprocessing Data

# %%
preprocessed_datasets = snv.preprocess_stocks_data(datasets)
# Out:
# GAZP data is ready. Time takes: 0 seconds

# %% [markdown]
# # Build and Fit models (not necessary, they are already built)

# %%
snv.build_fit_stocks_model(preprocessed_datasets, symbols=['GAZP'])
# Out:
# ...
# 65/65 [==============================] - 0s 750us/step
# GAZP data is ready. Time takes: 11 seconds. MAE: 3.83 rub. R2: 0.99
# ...
# 65/65 [==============================] - 0s 719us/step
# GAZP data is ready. Time takes: 4 seconds. MAE: 2.60 rub. R2: 0.99
# All models have been saved in "models_" folder

# %% [markdown]
# # Predicting

# %%
preds = snv.predict_future_stock_price(preprocessed_datasets, future_days=5, symbol='GAZP')

# %%
import pandas as pd
pd.DataFrame(preds)
# Out:
#                      0
# 2024-04-02  156.195435
# 2024-04-03  155.820709
# 2024-04-04  154.632050
# 2024-04-05  153.935455

# %%
preprocessed_datasets['GAZP']
# Out:
#              close  year  month  day  dayofweek  hour   lag_1   lag_2   lag_3  \
# TRADEDATE
# 2016-01-04  134.91  2016      1    4          0     0     NaN     NaN     NaN
# 2016-01-05  136.45  2016      1    5          1     0  134.91     NaN     NaN
# 2016-01-06  135.94  2016      1    6          2     0  136.45  134.91     NaN
# 2016-01-11  131.38  2016      1   11          0     0  135.94  136.45  134.91
# 2016-01-12  133.54  2016      1   12          1     0  131.38  135.94  136.45
# ...            ...   ...    ...  ...        ...   ...     ...     ...     ...
# 2024-03-26  157.94  2024      3   26          1     0  158.84  156.44  158.28
# 2024-03-27  157.79  2024      3   27          2     0  157.94  158.84  156.44
# 2024-03-28  157.05  2024      3   28          3     0  157.79  157.94  158.84
# 2024-03-29  157.22  2024      3   29          4     0  157.05  157.79  157.94
# 2024-04-01  158.06  2024      4    1          0     0  157.22  157.05  157.79
#
# ...
